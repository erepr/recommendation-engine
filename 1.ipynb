# %%
import pandas as pd

df = pd.read_csv("jobs.csv")
df
# Out:
#       Unnamed: 0   Created_date                        Due_date   Job_id  \
# 0              0  Nov 16, 2020                December 18, 2020  1731482
# 1              1  Nov 16, 2020   Hiring more, till Dec 17, 2020  1731479
# 2              2  Nov 16, 2020                December 16, 2020  1731480
# 3              3  Nov 16, 2020                December 16, 2020  1731476
# 4              4  Nov 16, 2020                December 16, 2020  1731463
# ...          ...            ...                             ...      ...
# 1460        1460  Feb 11, 2017                    June 21, 2030  1331813
# 1461        1461  Dec 14, 2016                     May 01, 2023  1314351
# 1462        1462  Mar 14, 2016                   April 27, 2021  1225615
# 1463        1463  Sep 30, 2015                December 31, 2023  1174444
# 1464        1464  Nov 26, 2020                November 30, 2020  1731424
#
#                Payment_type  \
# 0               Fixed Price
# 1     Fixed Price or Hourly
# ...

# %%
df['Category'].unique
# Out:
# <bound method Series.unique of 0       Programming & Development
# 1       Programming & Development
# 2                    Design & Art
# 3       Programming & Development
# 4                    Design & Art
#                   ...
# 1460                        Other
# 1461            Sales & Marketing
# 1462                        Other
# 1463                 Design & Art
# 1464    Programming & Development
# Name: Category, Length: 1465, dtype: object>

# %%
df2 = df[['Job_title', 'Job_description', 'Budget', 'Category' , 'Subcategory']]
df2
# Out:
#                                      Job_title  \
# 0         Society Management app (Android/IOS)
# 1                  GPRS tracking device/Server
# 2               create + edit two certificates
# 3                        2 WEBSITE DEVELOPMENT
# 4              digital coloring work for comic
# ...                                        ...
# 1460   Help create networks from RNA Seq. data
# 1461  SEO my site who sell instagram followers
# 1462     Analyzing microarray time series data
# 1463  Need a Custom, Print-Ready Folder Design
# 1464            get a Google developer account
#
#                                         Job_description  \
# 0     We are looking for mobile app developer (fulls...
# 1     I want to be able to track vehicles thus neede...
# 2     I need a graphics artist/photoshop/illustrator...
# 3     We need two website design\n\n1. This process ...
# 4     looking for digital coloring work for kids com...
# ...

# %%
df2['Budget']
# Out:
# 0                                         [' Under $250']
# 1                                                     NaN
# 2                                         [' Under $250']
# 3                                          [' $1k-$2.5k']
# 4                                         [' Under $250']
#                               ...
# 1460    [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 1461         [' $5 - $10 ', ' 30+ hrs/wk ', ' 6+ months']
# 1462    [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 1463                                        [' $500-$1k']
# 1464                                       [' $250-$500']
# Name: Budget, Length: 1465, dtype: object

# %%
new = df2["Budget"].str.split(",", n = 2, expand = True)

# %%
df2["First"] = new[0]
df2["Second"] = new[1]
df2["Third"] = new[2]
# Out:
# C:\Users\akshay\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\akshay\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\akshay\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df2[['Budget', 'First', 'Second', 'Third']]
# Out:
#                                                  Budget  \
# 0                                       [' Under $250']
# 1                                                   NaN
# 2                                       [' Under $250']
# 3                                        [' $1k-$2.5k']
# 4                                       [' Under $250']
# ...                                                 ...
# 1460  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 1461       [' $5 - $10 ', ' 30+ hrs/wk ', ' 6+ months']
# 1462  [' No rate specified ', ' 10-30 hrs/wk ', ' 6+...
# 1463                                      [' $500-$1k']
# 1464                                     [' $250-$500']
#
#                        First             Second           Third
# 0            [' Under $250']               None            None
# 1                        NaN                NaN             NaN
# 2            [' Under $250']               None            None
# ...
